# %%
import sys, os
sys.path.append(os.path.abspath(".."))

# %%
from stabilizer_framework.stabilizer_code import create_3qubit_bitflip_stabilizer

code = create_3qubit_bitflip_stabilizer()
code.print_info()

errors = ["XII", "IXI", "IIX", "XXX", "ZII", "IIZ"]
for e in errors:
    syn = code.syndrome(e)
    print(f"error {e} -> syndrome {syn}")
# Out:
# Stabilizer code with n = 3
# Stabilizer generators:
#   g1 = ZZI
#   g2 = IZZ
# error XII -> syndrome [1, 0]
# error IXI -> syndrome [1, 1]
# error IIX -> syndrome [0, 1]
# error XXX -> syndrome [0, 0]
# error ZII -> syndrome [0, 0]
# error IIZ -> syndrome [0, 0]
